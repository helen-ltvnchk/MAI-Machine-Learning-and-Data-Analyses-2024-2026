# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
data = pd.read_csv('salaries.csv', sep=',')
data.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %% [markdown]
# About dataset:
#
# This dataset provides insights into data engineer salaries and employment attributes for the year 2024. It includes information such as salary, job title, experience level, employment type, employee residence, remote work ratio, company location, and company size.
#
# The dataset allows for analysis of salary trends, employment patterns, and geographic variations in data engineering roles. It can be used by researchers, analysts, and organizations to understand the evolving landscape of data engineering employment and compensation.
#
# https://www.kaggle.com/datasets/chopper53/data-engineer-salary-in-2024

# %%
salaries = data['salary_in_usd'].dropna()

plt.hist(salaries, bins=20, density=True, alpha=0.6, color="b", label="Зарплаты в USD")

mu_2, std_2 = salaries.mean(), salaries.std()

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu_2, std_2)

plt.plot(x, p, "k", linewidth=2, label="Нормальное распределение")

plt.title("Распределение зарплат в USD")
plt.xlabel("Зарплата (USD)")
plt.ylabel("Плотность")
plt.legend()
plt.show()

# %% [markdown]
# Непрерывное распределение, близкое к нормальному.

# %%
mean_value_salary = data['salary_in_usd'].mean()
print(f"Математическое ожидание: {mean_value_salary:.3f} USD")

variance_salary = data['salary_in_usd'].var()
print(f"Дисперсия: {variance_salary:.3f} USD²")

skewness_salary = data['salary_in_usd'].skew()
print(f"Асимметрия: {skewness_salary:.3f}")

kurtosis_salary = data['salary_in_usd'].kurtosis()
print(f"Эксцесс: {kurtosis_salary:.3f}")

quantile_05_salary = data['salary_in_usd'].quantile(0.05)
quantile_95_salary = data['salary_in_usd'].quantile(0.95)
print(f"Квантиль 0,05: {quantile_05_salary:.3f} USD")
print(f"Квантиль 0,95: {quantile_95_salary:.3f} USD")

quantile_025_salary = data['salary_in_usd'].quantile(0.025)
print(f"2,5%-ная точка: {quantile_025_salary:.3f} USD")
# Out:
# Математическое ожидание: 149686.778 USD
# Дисперсия: 4692975190.437 USD²
# Асимметрия: 1.488
# Эксцесс: 7.618
# Квантиль 0,05: 55395.300 USD
# Квантиль 0,95: 265000.000 USD
# 2,5%-ная точка: 45393.925 USD

# %% [markdown]
# Математическое ожидание: 149686.778 USD
# Дисперсия: 4692975190.437 USD²
# Асимметрия: 1.488
# Эксцесс: 7.618
# Квантиль 0,05: 55395.300 USD
# Квантиль 0,95: 265000.000 USD
# 2,5%-ная точка: 45393.925 USD

# %%
### Датасет из Лабортаорной работы №1 (источник - kaggle.com)

data_wine = pd.read_csv('winequality-red.csv', sep=';')
data_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine = data_wine['density'].dropna()

plt.hist(wine, bins=20, density=True, alpha=0.6, color="b", label="Зарплаты в USD")

mu_2, std_2 = wine.mean(), wine.std()

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu_2, std_2)

plt.plot(x, p, "k", linewidth=2, label="Нормальное распределение")

plt.title("Распределение зарплат в USD")
plt.xlabel("Зарплата (USD)")
plt.ylabel("Плотность")
plt.legend()
plt.show()

# %%
mean_value_wine = data_wine['density'].mean()
print(f"Математическое ожидание: {mean_value_wine:.3f} USD")

variance_wine = data_wine['density'].var()
print(f"Дисперсия: {variance_wine:.3f} USD²")

skewness_wine = data_wine['density'].skew()
print(f"Асимметрия: {skewness_wine:.3f}")

kurtosis_wine = data_wine['density'].kurtosis()
print(f"Эксцесс: {kurtosis_wine:.3f}")

quantile_05_wine = data_wine['density'].quantile(0.05)
quantile_95_wine = data_wine['density'].quantile(0.95)
print(f"Квантиль 0,05: {quantile_05_wine:.3f} USD")
print(f"Квантиль 0,95: {quantile_95_wine:.3f} USD")

quantile_025_wine = data_wine['density'].quantile(0.025)
print(f"2,5%-ная точка: {quantile_025_wine:.3f} USD")
# Out:
# Математическое ожидание: 0.997 USD
# Дисперсия: 0.000 USD²
# Асимметрия: 0.071
# Эксцесс: 0.934
# Квантиль 0,05: 0.994 USD
# Квантиль 0,95: 1.000 USD
# 2,5%-ная точка: 0.993 USD

# %% [markdown]
# Математическое ожидание: 0.997 USD
# Дисперсия: 4692975190.437 USD²
# Асимметрия: 1.488
# Эксцесс: 7.618
# Квантиль 0,05: 0.994 USD
# Квантиль 0,95: 1.000 USD
# 2,5%-ная точка: 0.993 USD
